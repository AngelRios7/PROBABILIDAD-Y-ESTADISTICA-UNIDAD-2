# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelRios7/PROBABILIDAD-Y-ESTADISTICA-UNIDAD-2/blob/main/Probabilidad_U2_Programa3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadística
#
# ## Unidad 2
#
# ### Facilitador: Jose Gabriel Rodriguez Rivas
#
# ### Alumno: Angel Rios
#
# ### **Programa 3**

# %%
import math as mt
from itertools import permutations, combinations
def calcular_conteo_completo(n, r):
    if r > n:
        return "Error: r no puede ser mayor que n"

    # 1. Cálculo de Permutaciones
    # Fórmula: n! / (n - r)!
    p_n_r = mt.factorial(n) / mt.factorial(n - r)
    # 2. Cálculo de Combinaciones
    # Fórmula: n! / (r! * (n - r)!)
    c_n_r = mt.factorial(n) / (mt.factorial(r) * mt.factorial(n - r))
    print(f"Análisis para n={n} y r={r}")
    print(f"Permutaciones (P): {int(p_n_r)}")
    print(f"Combinaciones (C): {int(c_n_r)}")
    print("-" * 35)
    return p_n_r, c_n_r

# Resolucion del Ejercicio de los asistentes
# "Diez asistentes disponibles (n=10) para 4 preguntas (r=4)"
n_asistentes = 10
r_preguntas = 4

# Lista de identificadores para los asistentes
asistentes = [f"Asistente {i}" for i in range(1, n_asistentes + 1)]

# Ejecutar calculos
p, c = calcular_conteo_completo(n_asistentes, r_preguntas)

print(f"Como cada pregunta requiere un asistente diferente, el orden importa.")
print(f"Existen {int(p)} formas de asignarlos.")

# Generar y mostrar las primeras 5 posibilidades como ejemplo
print("\nEjemplos de asignaciones posibles (Asistente pregunta 1, 2, 3, 4):")
lista_p = list(permutations(asistentes, r_preguntas))
for i in range(5):
    print(f"Opción {i+1}: {lista_p[i]}")
# Out:
# Análisis para n=10 y r=4
# Permutaciones (P): 5040
# Combinaciones (C): 210
# -----------------------------------
# Como cada pregunta requiere un asistente diferente, el orden importa.
# Existen 5040 formas de asignarlos.
#
# Ejemplos de asignaciones posibles (Asistente pregunta 1, 2, 3, 4):
# Opción 1: ('Asistente 1', 'Asistente 2', 'Asistente 3', 'Asistente 4')
# Opción 2: ('Asistente 1', 'Asistente 2', 'Asistente 3', 'Asistente 5')
# Opción 3: ('Asistente 1', 'Asistente 2', 'Asistente 3', 'Asistente 6')
# Opción 4: ('Asistente 1', 'Asistente 2', 'Asistente 3', 'Asistente 7')
# Opción 5: ('Asistente 1', 'Asistente 2', 'Asistente 3', 'Asistente 8')
